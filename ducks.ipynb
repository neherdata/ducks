# %%
import requests
from IPython.display import Image

# %%
url = 'https://random-d.uk/api/v2/random'
r = requests.get(url)

# %%
resp = r.json()
urlDuck = resp.get('url')

# %%
Image(requests.get(urlDuck).content)
